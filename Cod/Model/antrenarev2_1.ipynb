# %%
import os

from sklearn.metrics import confusion_matrix, classification_report

os.environ['TF_ENABLE_ONEDNN_OPTS']= '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import keras as kr
from keras.callbacks import EarlyStopping

from sklearn.utils.class_weight import compute_class_weight

# %%
set_date_antrenare = kr.utils.image_dataset_from_directory(
    'D:/Licenta/DataSetOrganized/data/train',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
    pad_to_aspect_ratio=False,
    data_format=None,
    format="tf",
    verbose=True,
)

set_date_validare = kr.utils.image_dataset_from_directory(
    'D:/Licenta/DataSetOrganized/data/validation',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256),
    shuffle=False,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
    pad_to_aspect_ratio=False,
    data_format=None,
    format="tf",
    verbose=True,
)

set_date_testare = kr.utils.image_dataset_from_directory(
    'D:/Licenta/DataSetOrganized/data/test',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256),
    shuffle=False,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
    pad_to_aspect_ratio=False,
    data_format=None,
    format="tf",
    verbose=True,
)
# Out:
# Found 3000 files belonging to 5 classes.
# Found 600 files belonging to 5 classes.
# Found 400 files belonging to 5 classes.

# %%
model_data_augumentation = kr.Sequential([kr.layers.RandomFlip("horizontal_and_vertical"),kr.layers.RandomBrightness(0.2),kr.layers.RandomContrast(0.2)],name="augumentare_date")

# %%
def squeeze_excite_block(tensor,ratio=16):
    filters = tensor.shape[-1]
    s_e_b = kr.layers.GlobalAvgPool2D()(tensor)
    s_e_b = kr.layers.Dense(filters // ratio,activation = 'relu' , kernel_initializer='he_normal')(s_e_b)
    s_e_b = kr.layers.Dense(filters,activation='sigmoid')(s_e_b)
    s_e_b = kr.layers.Reshape((1,1,filters))(s_e_b)
    return kr.layers.Multiply()([tensor,s_e_b])

# %%
inputs = kr.layers.Input(shape=(256,256,3))


x = model_data_augumentation(inputs)
x =  kr.layers.Rescaling(1./255)(x)

x = kr.layers.Conv2D(64,3,padding ='same',kernel_initializer='he_normal')(x)
x = kr.layers.BatchNormalization()(x)
x = kr.layers.Activation('relu')(x)
x = squeeze_excite_block(x)
x = kr.layers.MaxPooling2D(2,2)(x)

x = kr.layers.Conv2D(128,3,padding ='same',kernel_initializer='he_normal')(x)
x = kr.layers.BatchNormalization()(x)
x = kr.layers.Activation('relu')(x)
x = squeeze_excite_block(x)
x = kr.layers.MaxPooling2D(2,2)(x)


x = kr.layers.Conv2D(256,3,padding ='same',kernel_initializer='he_normal')(x)
x = kr.layers.BatchNormalization()(x)
x = kr.layers.Activation('relu')(x)
x = squeeze_excite_block(x)
x = kr.layers.MaxPooling2D(2,2)(x)


x = kr.layers.GlobalAveragePooling2D()(x)
x = kr.layers.Dense(256, activation='relu')(x)
x = kr.layers.Dropout(0.5)(x)
outputs = kr.layers.Dense(5, activation='softmax')(x)

model_antrenare = kr.models.Model(inputs = inputs, outputs = outputs)

optimizator = tf.keras.optimizers.AdamW(learning_rate=0.0002,weight_decay=1e-4)

model_antrenare.compile(optimizer=optimizator, loss='sparse_categorical_crossentropy',metrics=['accuracy'])

reduce_lr = kr.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,patience=10,min_lr=1e-6,verbose=1)

early_stop = kr.callbacks.EarlyStopping(monitor='val_loss', patience=20, verbose=1,restore_best_weights=True,start_from_epoch=5)

model_antrenare.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ augumentare_date    │ (None, 256, 256,  │          0 │ input_layer[0][0] │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 256, 256,  │          0 │ augumentare_date… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │      1,792 │ rescaling[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ activation[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 4)         │        260 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │        320 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 64)  │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 256, 256,  │          0 │ activation[0][0], │
# │                     │ 64)               │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ multiply[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_1[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 8)         │      1,032 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │      1,152 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 128) │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 128, 128,  │          0 │ activation_1[0][… │
# │ (Multiply)          │ 128)              │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ multiply_1[0][0]  │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ activation_2[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 16)        │      4,112 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 256)       │      4,352 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 1, 1, 256) │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 64, 64,    │          0 │ activation_2[0][… │
# │ (Multiply)          │ 256)              │            │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ multiply_2[0][0]  │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ max_pooling2d_2[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 256)       │     65,792 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 5)         │      1,285 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 450,913 (1.72 MB)
#  Trainable params: 450,017 (1.72 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
y_train = np.concatenate([y for x,y in set_date_antrenare],axis=0)
clase_unice = np.unique(y_train)

class_weights_array = compute_class_weight(class_weight='balanced',classes=clase_unice,y=y_train)
class_weights_dict = dict(zip(clase_unice,class_weights_array))

print(class_weights_dict)
# Out:
# {np.int32(0): np.float64(1.0), np.int32(1): np.float64(1.0), np.int32(2): np.float64(1.0), np.int32(3): np.float64(1.0), np.int32(4): np.float64(1.0)}

# %%
model_antrenare_istoric = model_antrenare.fit(x=set_date_antrenare,validation_data = set_date_validare,epochs=60,callbacks=[early_stop,reduce_lr],class_weight=class_weights_dict)
# Out:
# Epoch 1/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.5153 - loss: 1.1953 - val_accuracy: 0.2000 - val_loss: 1.7408 - learning_rate: 2.0000e-04
# Epoch 2/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 329s 3s/step - accuracy: 0.5870 - loss: 1.0306 - val_accuracy: 0.2283 - val_loss: 2.0341 - learning_rate: 2.0000e-04
# Epoch 3/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 323s 3s/step - accuracy: 0.6173 - loss: 0.9689 - val_accuracy: 0.2950 - val_loss: 1.8966 - learning_rate: 2.0000e-04
# Epoch 4/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 323s 3s/step - accuracy: 0.6357 - loss: 0.9215 - val_accuracy: 0.3600 - val_loss: 1.4706 - learning_rate: 2.0000e-04
# Epoch 5/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 322s 3s/step - accuracy: 0.6483 - loss: 0.8867 - val_accuracy: 0.4300 - val_loss: 1.4297 - learning_rate: 2.0000e-04
# Epoch 6/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.6520 - loss: 0.8682 - val_accuracy: 0.5333 - val_loss: 1.1088 - learning_rate: 2.0000e-04
# Epoch 7/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 324s 3s/step - accuracy: 0.6693 - loss: 0.8242 - val_accuracy: 0.5500 - val_loss: 1.0536 - learning_rate: 2.0000e-04
# Epoch 8/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 215s 2s/step - accuracy: 0.6767 - loss: 0.8180 - val_accuracy: 0.5750 - val_loss: 0.9423 - learning_rate: 2.0000e-04
# Epoch 9/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 210s 2s/step - accuracy: 0.6903 - loss: 0.7830 - val_accuracy: 0.5817 - val_loss: 0.9671 - learning_rate: 2.0000e-04
# Epoch 10/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 210s 2s/step - accuracy: 0.6963 - loss: 0.7815 - val_accuracy: 0.6283 - val_loss: 0.8975 - learning_rate: 2.0000e-04
# Epoch 11/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 247s 3s/step - accuracy: 0.7173 - loss: 0.7294 - val_accuracy: 0.5900 - val_loss: 0.9386 - learning_rate: 2.0000e-04
# Epoch 12/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 331s 3s/step - accuracy: 0.7213 - loss: 0.7104 - val_accuracy: 0.6050 - val_loss: 0.8678 - learning_rate: 2.0000e-04
# Epoch 13/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.7250 - loss: 0.7013 - val_accuracy: 0.6133 - val_loss: 0.9143 - learning_rate: 2.0000e-04
# Epoch 14/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 323s 3s/step - accuracy: 0.7443 - loss: 0.6701 - val_accuracy: 0.5683 - val_loss: 0.9945 - learning_rate: 2.0000e-04
# Epoch 15/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.7467 - loss: 0.6476 - val_accuracy: 0.5450 - val_loss: 1.0693 - learning_rate: 2.0000e-04
# Epoch 16/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 325s 3s/step - accuracy: 0.7560 - loss: 0.6350 - val_accuracy: 0.5983 - val_loss: 1.1790 - learning_rate: 2.0000e-04
# Epoch 17/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.7583 - loss: 0.6165 - val_accuracy: 0.5933 - val_loss: 0.9373 - learning_rate: 2.0000e-04
# Epoch 18/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.7783 - loss: 0.5954 - val_accuracy: 0.7183 - val_loss: 0.7035 - learning_rate: 2.0000e-04
# Epoch 19/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.7780 - loss: 0.5874 - val_accuracy: 0.6083 - val_loss: 0.9940 - learning_rate: 2.0000e-04
# Epoch 20/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 324s 3s/step - accuracy: 0.7880 - loss: 0.5560 - val_accuracy: 0.7217 - val_loss: 0.6948 - learning_rate: 2.0000e-04
# Epoch 21/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 322s 3s/step - accuracy: 0.7887 - loss: 0.5417 - val_accuracy: 0.6983 - val_loss: 0.7505 - learning_rate: 2.0000e-04
# Epoch 22/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 323s 3s/step - accuracy: 0.7997 - loss: 0.5271 - val_accuracy: 0.7067 - val_loss: 0.7205 - learning_rate: 2.0000e-04
# Epoch 23/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 323s 3s/step - accuracy: 0.7977 - loss: 0.5230 - val_accuracy: 0.5833 - val_loss: 1.1471 - learning_rate: 2.0000e-04
# Epoch 24/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 317s 3s/step - accuracy: 0.8237 - loss: 0.4757 - val_accuracy: 0.6017 - val_loss: 1.0260 - learning_rate: 2.0000e-04
# Epoch 25/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 320s 3s/step - accuracy: 0.8183 - loss: 0.4680 - val_accuracy: 0.6900 - val_loss: 0.8284 - learning_rate: 2.0000e-04
# Epoch 26/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 323s 3s/step - accuracy: 0.8213 - loss: 0.4674 - val_accuracy: 0.6467 - val_loss: 1.0549 - learning_rate: 2.0000e-04
# Epoch 27/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 227s 2s/step - accuracy: 0.8173 - loss: 0.4707 - val_accuracy: 0.7417 - val_loss: 0.6905 - learning_rate: 2.0000e-04
# Epoch 28/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 325s 3s/step - accuracy: 0.8267 - loss: 0.4405 - val_accuracy: 0.7250 - val_loss: 0.8102 - learning_rate: 2.0000e-04
# Epoch 29/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 323s 3s/step - accuracy: 0.8327 - loss: 0.4346 - val_accuracy: 0.7400 - val_loss: 0.7474 - learning_rate: 2.0000e-04
# Epoch 30/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 321s 3s/step - accuracy: 0.8430 - loss: 0.4096 - val_accuracy: 0.7017 - val_loss: 0.7716 - learning_rate: 2.0000e-04
# Epoch 31/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 322s 3s/step - accuracy: 0.8363 - loss: 0.4200 - val_accuracy: 0.6733 - val_loss: 1.0679 - learning_rate: 2.0000e-04
# Epoch 32/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 225s 2s/step - accuracy: 0.8530 - loss: 0.3945 - val_accuracy: 0.7650 - val_loss: 0.7177 - learning_rate: 2.0000e-04
# Epoch 33/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 210s 2s/step - accuracy: 0.8460 - loss: 0.3930 - val_accuracy: 0.6933 - val_loss: 0.9007 - learning_rate: 2.0000e-04
# Epoch 34/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 208s 2s/step - accuracy: 0.8480 - loss: 0.3955 - val_accuracy: 0.7367 - val_loss: 0.9120 - learning_rate: 2.0000e-04
# Epoch 35/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 210s 2s/step - accuracy: 0.8583 - loss: 0.3652 - val_accuracy: 0.7850 - val_loss: 0.6866 - learning_rate: 2.0000e-04
# Epoch 36/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 299s 3s/step - accuracy: 0.8433 - loss: 0.4051 - val_accuracy: 0.7667 - val_loss: 0.7353 - learning_rate: 2.0000e-04
# Epoch 37/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.8703 - loss: 0.3458 - val_accuracy: 0.7533 - val_loss: 0.7661 - learning_rate: 2.0000e-04
# Epoch 38/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 322s 3s/step - accuracy: 0.8710 - loss: 0.3417 - val_accuracy: 0.7200 - val_loss: 0.9665 - learning_rate: 2.0000e-04
# Epoch 39/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 325s 3s/step - accuracy: 0.8667 - loss: 0.3525 - val_accuracy: 0.7033 - val_loss: 0.8183 - learning_rate: 2.0000e-04
# Epoch 40/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 323s 3s/step - accuracy: 0.8647 - loss: 0.3514 - val_accuracy: 0.7750 - val_loss: 0.7958 - learning_rate: 2.0000e-04
# Epoch 41/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 294s 3s/step - accuracy: 0.8690 - loss: 0.3403 - val_accuracy: 0.7700 - val_loss: 0.7188 - learning_rate: 2.0000e-04
# Epoch 42/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 209s 2s/step - accuracy: 0.8763 - loss: 0.3179 - val_accuracy: 0.7383 - val_loss: 0.8428 - learning_rate: 2.0000e-04
# Epoch 43/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 209s 2s/step - accuracy: 0.8810 - loss: 0.3074 - val_accuracy: 0.7667 - val_loss: 0.9691 - learning_rate: 2.0000e-04
# Epoch 44/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 211s 2s/step - accuracy: 0.8903 - loss: 0.2923 - val_accuracy: 0.7567 - val_loss: 0.7434 - learning_rate: 2.0000e-04
# Epoch 45/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8788 - loss: 0.3165
# Epoch 45: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 209s 2s/step - accuracy: 0.8730 - loss: 0.3372 - val_accuracy: 0.6567 - val_loss: 1.1606 - learning_rate: 2.0000e-04
# Epoch 46/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 305s 3s/step - accuracy: 0.8917 - loss: 0.2970 - val_accuracy: 0.7750 - val_loss: 0.7383 - learning_rate: 1.0000e-04
# Epoch 47/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 209s 2s/step - accuracy: 0.9110 - loss: 0.2639 - val_accuracy: 0.7800 - val_loss: 0.7145 - learning_rate: 1.0000e-04
# Epoch 48/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 209s 2s/step - accuracy: 0.9050 - loss: 0.2525 - val_accuracy: 0.7867 - val_loss: 0.7074 - learning_rate: 1.0000e-04
# Epoch 49/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 211s 2s/step - accuracy: 0.9023 - loss: 0.2595 - val_accuracy: 0.7400 - val_loss: 0.8727 - learning_rate: 1.0000e-04
# Epoch 50/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 209s 2s/step - accuracy: 0.9023 - loss: 0.2586 - val_accuracy: 0.7950 - val_loss: 0.7560 - learning_rate: 1.0000e-04
# Epoch 51/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 282s 3s/step - accuracy: 0.9080 - loss: 0.2597 - val_accuracy: 0.8033 - val_loss: 0.6792 - learning_rate: 1.0000e-04
# Epoch 52/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 314s 3s/step - accuracy: 0.9030 - loss: 0.2620 - val_accuracy: 0.7833 - val_loss: 0.7383 - learning_rate: 1.0000e-04
# Epoch 53/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 325s 3s/step - accuracy: 0.9150 - loss: 0.2394 - val_accuracy: 0.7750 - val_loss: 0.7600 - learning_rate: 1.0000e-04
# Epoch 54/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 252s 3s/step - accuracy: 0.9153 - loss: 0.2307 - val_accuracy: 0.7900 - val_loss: 0.6974 - learning_rate: 1.0000e-04
# Epoch 55/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 210s 2s/step - accuracy: 0.9150 - loss: 0.2266 - val_accuracy: 0.8117 - val_loss: 0.6997 - learning_rate: 1.0000e-04
# Epoch 56/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 212s 2s/step - accuracy: 0.9117 - loss: 0.2394 - val_accuracy: 0.7733 - val_loss: 0.7881 - learning_rate: 1.0000e-04
# Epoch 57/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 210s 2s/step - accuracy: 0.9003 - loss: 0.2534 - val_accuracy: 0.7333 - val_loss: 1.0589 - learning_rate: 1.0000e-04
# Epoch 58/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 210s 2s/step - accuracy: 0.9137 - loss: 0.2360 - val_accuracy: 0.8083 - val_loss: 0.7245 - learning_rate: 1.0000e-04
# Epoch 59/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 212s 2s/step - accuracy: 0.9127 - loss: 0.2388 - val_accuracy: 0.8167 - val_loss: 0.6735 - learning_rate: 1.0000e-04
# Epoch 60/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 209s 2s/step - accuracy: 0.9187 - loss: 0.2256 - val_accuracy: 0.7600 - val_loss: 0.7989 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 59.

# %%
loss = model_antrenare_istoric.history['loss']
val_loss = model_antrenare_istoric.history['val_loss']
epochs = range(1, len(loss) + 1)


plt.figure(figsize = (10,6))
plt.plot(epochs, loss, 'r', label='Loss Antrenare')
plt.plot(epochs, val_loss, 'b', label='Loss Validare')
plt.title('Loss Antrenare vs Loss Validare')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()

# %%
accuracy = model_antrenare_istoric.history['accuracy']
val_accuracy = model_antrenare_istoric.history['val_accuracy']
epochs = range(1, len(accuracy) + 1)


plt.figure(figsize = (10,6))
plt.plot(epochs, accuracy, 'r', label='Accuracy Antrenare')
plt.plot(epochs, val_accuracy, 'b', label='Accuracy Validare')
plt.title('Accuracy Antrenare vs Accuracy Validare')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.show()

# %%
test_loss,test_accuracy = model_antrenare.evaluate(set_date_testare)
print(test_loss)
print(test_accuracy)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 365ms/step - accuracy: 0.8575 - loss: 0.5549
# 0.554878830909729
# 0.8575000166893005

# %%
val_loss,val_accuracy = model_antrenare.evaluate(set_date_validare)
print(val_loss)
print(val_accuracy)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 372ms/step - accuracy: 0.8167 - loss: 0.6735
# 0.673474133014679
# 0.8166666626930237

# %%
y_corect = np.concatenate([y for x,y in set_date_testare],axis=0)
prediction = model_antrenare.predict(set_date_testare)
y_prediction = np.argmax(prediction,axis=1)

class_name = set_date_testare.class_names


cm = confusion_matrix(y_corect,y_prediction)


plt.figure(figsize = (10,8))
sns.heatmap(cm,annot=True,fmt='g',cmap='Blues',xticklabels=class_name,yticklabels=class_name)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()


print(classification_report(y_corect,y_prediction,target_names=class_name))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 450ms/step
#                    precision    recall  f1-score   support
#
#       Anthracnose       0.83      0.69      0.75        80
#    Bacterial Wilt       1.00      0.95      0.97        80
#      Downy Mildew       0.78      0.79      0.78        80
# Gummy Stem Blight       0.76      0.88      0.81        80
#           Healthy       0.93      0.99      0.96        80
#
#          accuracy                           0.86       400
#         macro avg       0.86      0.86      0.86       400
#      weighted avg       0.86      0.86      0.86       400

# %%
import keras as kr
import numpy as np
import matplotlib.pyplot as plt

@kr.saving.register_keras_serializable()
def squeeze_excite_block(tensor, ratio=16):
    filters = tensor.shape[-1]
    s_e_b = kr.layers.GlobalAvgPool2D()(tensor)
    s_e_b = kr.layers.Dense(filters // ratio, activation='relu', kernel_initializer='he_normal')(s_e_b)
    s_e_b = kr.layers.Dense(filters, activation='sigmoid')(s_e_b)
    s_e_b = kr.layers.Reshape((1, 1, filters))(s_e_b)
    return kr.layers.Multiply()([tensor, s_e_b])

model_antrenare = kr.models.load_model(
    'model_antrenare_licenta_v2.keras',
    custom_objects={'squeeze_excite_block': squeeze_excite_block}
)

# %%
cale_poze = r'D:\Licenta\DataSetOrganized\data\test\Anthracnose\Anthracnose (723).jpg'
clase = ['Anthracnose', 'Bacterial Wilt', 'Downy Mildew', 'Gummy Stem Blight', 'Healthy']
imagine_test = kr.utils.load_img(cale_poze, target_size=(256, 256))
imagine_array = kr.utils.img_to_array(imagine_test)
imagine_array = np.expand_dims(imagine_array, axis=0)

predictii = model_antrenare.predict(imagine_array)
index = np.argmax(predictii[0])
boala_detectata = clase[index]
siguranta = predictii[0][index] * 100

plt.imshow(imagine_test)
plt.title(f"Diagnostic AI: {boala_detectata}\nConfidence: {siguranta:.2f}%", fontsize=14, color='green')
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %%
cale_poze = r'D:\Licenta\DataSetOrganized\data\test\Bacterial Wilt\Bacterial Wilt (722).jpg'
clase = ['Anthracnose', 'Bacterial Wilt', 'Downy Mildew', 'Gummy Stem Blight', 'Healthy']
imagine_test = kr.utils.load_img(cale_poze, target_size=(256, 256))
imagine_array = kr.utils.img_to_array(imagine_test)
imagine_array = np.expand_dims(imagine_array, axis=0)

predictii = model_antrenare.predict(imagine_array)
index = np.argmax(predictii[0])
boala_detectata = clase[index]
siguranta = predictii[0][index] * 100

plt.imshow(imagine_test)
plt.title(f"Diagnostic AI: {boala_detectata}\nConfidence: {siguranta:.2f}%", fontsize=14, color='green')
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
cale_poze = r'D:\Licenta\DataSetOrganized\data\test\Downy Mildew\Downy Mildew (722).jpg'
clase = ['Anthracnose', 'Bacterial Wilt', 'Downy Mildew', 'Gummy Stem Blight', 'Healthy']
imagine_test = kr.utils.load_img(cale_poze, target_size=(256, 256))
imagine_array = kr.utils.img_to_array(imagine_test)
imagine_array = np.expand_dims(imagine_array, axis=0)

predictii = model_antrenare.predict(imagine_array)
index = np.argmax(predictii[0])
boala_detectata = clase[index]
siguranta = predictii[0][index] * 100

plt.imshow(imagine_test)
plt.title(f"Diagnostic AI: {boala_detectata}\nConfidence: {siguranta:.2f}%", fontsize=14, color='green')
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
cale_poze = r'D:\Licenta\DataSetOrganized\data\test\Gummy Stem Blight\Gummy Stem Blight (722).jpg'
clase = ['Anthracnose', 'Bacterial Wilt', 'Downy Mildew', 'Gummy Stem Blight', 'Healthy']
imagine_test = kr.utils.load_img(cale_poze, target_size=(256, 256))
imagine_array = kr.utils.img_to_array(imagine_test)
imagine_array = np.expand_dims(imagine_array, axis=0)

predictii = model_antrenare.predict(imagine_array)
index = np.argmax(predictii[0])
boala_detectata = clase[index]
siguranta = predictii[0][index] * 100

plt.imshow(imagine_test)
plt.title(f"Diagnostic AI: {boala_detectata}\nConfidence: {siguranta:.2f}%", fontsize=14, color='green')
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
cale_poze = r'D:\Licenta\DataSetOrganized\data\test\Healthy\Fresh Leaf (722).jpg'
clase = ['Anthracnose', 'Bacterial Wilt', 'Downy Mildew', 'Gummy Stem Blight', 'Healthy']
imagine_test = kr.utils.load_img(cale_poze, target_size=(256, 256))
imagine_array = kr.utils.img_to_array(imagine_test)
imagine_array = np.expand_dims(imagine_array, axis=0)

predictii = model_antrenare.predict(imagine_array)
index = np.argmax(predictii[0])
boala_detectata = clase[index]
siguranta = predictii[0][index] * 100

plt.imshow(imagine_test)
plt.title(f"Diagnostic AI: {boala_detectata}\nConfidence: {siguranta:.2f}%", fontsize=14, color='green')
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
model_antrenare.save('model_antrenare_licenta_v2.keras')
